# %% [markdown]
# # Environment check

# %%
import platform
import sys
from pathlib import Path

import chunkbench
from chunkbench.common.environment import environment_fingerprint

print(sys.version)
print(platform.platform())
print(environment_fingerprint(Path.cwd()))
print('package:', chunkbench.__version__)
